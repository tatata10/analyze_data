# %%
import google.generativeai as genai

# APIキーを設定
genai.configure(api_key="AIzaSyBo4qp2tWn_1-WoPVyAoj9o2-W_qE6r3dA")

# モデルを選択してプロンプトを送信
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content("パチスロの新台情報を教えて")
print(response.text)
# Out:
# 申し訳ありませんが、私はリアルタイムの情報を取得できませんので、最新のパチスロ新台情報については、以下の方法で確認することをお勧めします。
#
# * **パチスロ情報サイト:**  多くのウェブサイトがパチスロの新台情報を掲載しています。  有名どころのサイトをいくつか検索してみてください。（例：「パチスロ 新台 情報」で検索）  ただし、情報の正確性には注意が必要です。
#
# * **メーカー公式ウェブサイト:**  各パチスロメーカー（例えば、オリンピア、平和、SANKYOなど）の公式サイトには、新機種の情報が掲載されることが多いです。
#
# * **パチスロ雑誌:**  専門誌では、新台の情報が詳しく掲載されています。
#
# * **ホールのウェブサイト:**  お近くのホールのウェブサイトをチェックすると、導入予定機種の情報が載っている場合があります。
#
#
# これらの情報源を組み合わせることで、最新で信頼性の高い情報を得ることができるでしょう。  新台情報は非常に頻繁に更新されるため、常に最新の情報を確認するようにしてください。

# %%
import tweepy

# 環境変数からTwiiter APIキーを取得する
consumerKey = "ygXeoXjnckytKWRj9SdDiwiQh"
consumerSecret = "swy4e6DUDgoqntjbcrUoQyUamvehAgjAO0FPY6qnMDujXyTIfY"
accessToken = "1917385675651047425-lcwmFiaQeItVCI58xEz20Sc0dp0Yny"
accessTokenSecret = "JidAwRmb4h1OuSptDm4PksdfFbuI3gzKdzRd3AoI7pX8q"
bearerToken = "AAAAAAAAAAAAAAAAAAAAAKLI0wEAAAAALjDlr5%2B7HHvETsygnoRbNJgRERU%3Dif6eQiTszdJKNAdlS51lQkbcRZlquCEuCc12dFWD7Xw0GrZ2wv"

# ツイート作成関数
def post(tweet):

    client = tweepy.Client(
        bearerToken,
        consumerKey,
        consumerSecret,
        accessToken,
        accessTokenSecret
    )

    client.create_tweet(text=tweet)

post("よろしくお願いします。")
